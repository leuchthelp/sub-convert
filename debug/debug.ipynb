# %%
import pandas as pd

df = pd.read_json(
    "/workspaces/sup-convert/image-test/debug-4430cabf6d519f4b9a0410e1d3a8296539e3dd9790a3c89d169806f78902a7b0.json"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/venv/lib/python3.14/site-packages/pandas/io/json/_json.py:948, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     947 try:
# --> 948     self.handles = get_handle(
#     949         filepath_or_buffer,
#     950         "r",
#     951         encoding=self.encoding,
#     952         compression=self.compression,
#     953         storage_options=self.storage_options,
#     954         errors=self.encoding_errors,
#     955     )
#     956 except OSError as err:
#
# File /opt/venv/lib/python3.14/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     924 if ioargs.encoding and "b" not in ioargs.mode:
#     925     # Encoding
# --> 926     handle = open(
#     927         handle,
#     928         ioargs.mode,
# ...

# %%
import plotly.express as px

fig = px.timeline(
    data_frame=df,
    x_start="start",
    x_end="end",
    y="placement",
    hover_name="text",
    hover_data="text",
    color="placement",
)

fig.show()
# Out:
# /opt/venv/lib/python3.13/site-packages/narwhals/_pandas_like/series_str.py:77: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   result = self.implementation.to_native_namespace().to_datetime(
# /opt/venv/lib/python3.13/site-packages/narwhals/_pandas_like/series_str.py:77: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   result = self.implementation.to_native_namespace().to_datetime(
