# %%
import pandas as pd

df = pd.read_json(
    "/workspaces/sup-convert/debug/4430ca-Hells Paradise S01e06.mkv-5/4430ca.json"
)

# %%
import plotly.express as px

fig = px.timeline(
    data_frame=df,
    x_start="start",
    x_end="end",
    y="placement",
    hover_name="text",
    hover_data="text",
    color="placement",
)

fig.show()
