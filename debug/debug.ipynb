# %%
import pandas as pd

path = "debug/381454-Terror In Resonance S01e10.mkv-5/381454.json"


path = path.replace("debug/", "")
df = pd.read_json(path)

# %%
import plotly.express as px

fig = px.timeline(
    data_frame=df,
    x_start="start",
    x_end="end",
    y="placement",
    hover_name="text",
    hover_data="text",
    color="placement",
    color_discrete_map={
        "Top": "#AB029E",
        "Bottom": "#FF4430",
    },
    category_orders={"placement": ["Top", "Bottom"]},
)

fig.show()
